# %% [markdown]
# <center> <h1> Laboratorijas darbs #3.1

# %% [markdown]
# <center> <h2> Motoru cilindra spiediena datu analīze

# %% [markdown]
# <center> <h2> Ievads, materiāli un metodes

# %% [markdown]
# Šī darba mērķis ir nostiprināt un padziļināt zināšanas par sadedzes norisi dzirsketeļaizdedzes motorā. <br>
#
# Dati iegūti, lietojot instrumentētu automobiļa motoru ***Toyota 4AFE***. Motoram uzstādīts brīvi konfigurējams vadības modulis ***VEMS 3.6*** un platjoslas izplūdes gāzu skābekļa sensors ***BOSCH LSU 4.9.*** <br>
# Motors uz jaudas stenda RTU iekšdedzes motoru zinātniskajā laboratorijā ir parādīts sekojošā attēlā: <br>
# ![dyno.JPG](attachment:dyno.JPG)<br>
# <br>
# <div align="center">  1. att. Toytota 4AFE motors uz jaudas stenda RTU iekšdedzes motoru zinātniskajā laboratorijā   <br>
# <div align="left">
#
# Motora galvenie parametri:
# - veids: 4 taktu, dzirksteļaizdedzes;
# - gaisa padeve - atmosfēriskā;
# - cilindru skaits: 4;
# - cilindra diametrs un virzuļa gājiens: 81 x 77 mm;
# - klaņa garums: 130 mm;
# - kompresijas pakāpe 9.5. <br>
#
#
# Jaudas stends ***Shenck U1-16*** ir aprīkots ar ūdens bremzi. Bremzes radīto slodzi regulē ar ūdens uzplūdes leņķi, ko var mainīt ar rokturi. Motora kloķvārpsta griež ūdens bremzes rotoru. Bremzes stators ir pievienots tās korpusam, kurš arī cenšas pagriezties līdz ar rotoru. Stators ir fiksēts ar sviru, kuru ar rāmi savieno spēka sensors. Jaudas stenda bremzes darba princips ir parādīts 2. attēlā Nomērot spēku $F$ un zinot sviras garumu $b$, iespējams aprēķināt motora radīto griezes momentu. Kontroles rokturis un bremzes spēka sensora novietojums redzams 1. attēlā. <br> . <br>
# ![brake.JPG](attachment:brake.JPG)
#     <br>
# <div align="center">  2. att. Jaudas stenda bremzes darbības shēma   <br>
# <div align="left">
#     <div align="right">$[J.B. Heywood, 2018]$ <br> <br>
#
#
# ***
#
# Galvenie dati, kas iegūti izmēģinājumā, un tiks lietoti aprēķinam, ir ar kloķvārpstas rotāciju sinhronizēti gāzu spiediena mērījumi motora sadegšanas kamerā, kā arī degvielas patēriņš un efektīvais griezes moments (kloķvārpstas griezes moments). <br>
#
# Degvielas patēriņš tiek aprēķināts pēc iepriekš noteiktas degvielas sprauslu caurplūdes un sprauslu atvēruma laika, lietojot motora vadības moduļa ***VEMS*** kontroles programmatūru ***VEMS Tune***. <br>
#
# Kloķvārpstas pozīcija tiek noteikta ar ***Kistler*** optisko sensoru (enkoderu) un aizdedzes sveci ar iebūvētu pjezoelektrisku relatīvo cilindra spiediena sensoru. <br> Enkodera signālu A un B izšķirtspēja ir 0.1 grāds. <br> Cilindra spiediena un kloķvārpstas griezes momenta mērījumi izmēģinājuma laikā reģistrēti, saņemot enkodera impulsu A, kas lieciena, ka kloķvārpsta pagriezusies par 0.1 grādu. <br> Savukārt enkodera impulss Z paziņo, ka kloķvārpsta pagriezusies par vienu pilnu apgriezienu. Motora darba fāzes var atšķirt, papildus reģistrējot impulsu no parasta Hola veida devēja, kas izvietots pie sadales vārpstas skriemeļa un ģenerē vienu impuslu vienā apgriezienā, jeb pēc katra otrā kloķvārpstas apgrieziena. <br> Sensoru atrašanās vieta parādīta 3. attēlā. <br>
#
# ![encoder.jpg](attachment:encoder.jpg)   <br>
# <div align="center">   3. att. Kloķvārpstas pozīcijas sensora un cilindra spiediena sensora atrašanās vieta   <br>
# <div align="left">
# <br>
#
# Laboratorijas izkārtojums izmēģinājuma laikā parādīts 4. attēlā.<br>
#
#
# ![lab.JPG](attachment:lab.JPG)   <br>
# <div align="center">   4. att. Motora kontroles un datu ieguves modulārā iekārta izmēģinājumu laikā   <br>
# <div align="left">
#
# <br>
#
# Kloķvārpstas radītais griezes moments, kloķvārpstas pagrieziena leņķis un spiediens motora cilindrā tiek reģistrēts ar modulāru datu iekārtu, kas veidota no ***Nationals Instruments*** šasijas ***NI 9068*** un uzdevumam piemērotiem moduļiem.<br>
#
#
#
# ***
#
# Izmēģinājumi veikti sekojošos režīmos:
#
# - Vidējais efektīvais spiediens, apmēram: 3.4 bar;
# - Gaisa temperatūra ieplūdes kolektorā: 22°C;
# - Degviela - benzīns Circle K A95, blīvums 740 $kg/m^3$, zemākā siltumspēja 43 MJ/kg;
# - Gaisa/degvielas relatīvā attiecība $\lambda$: 0.9, 1.0, 1.1;
# - Aizdedzes apsteidze: 20; 25; 30 pirms AMP;
# - Motora kloķvārpstas apgriezieni, apmēram 1500 $min^{-1}$.<br>
#
# Papildus režīms ir bez degvielas iesmidzināšanas, tā saucamais motorings jeb brīvgriešana.<br>
# Motors uzsildīts darba temperatūrā (dzesēšanas šķidruma temperatūra 85°C), ieregulēti degvielas padeves parametri un reģistrēti cilindra spiediena dati. <br>
#
# Aprēķina piemērā veidosim kodu programmēšanas valodā Python.<br>
# Standarta Python videi pievienosim papildus funkciju bibliotēkas, kas atvieglo darbu inženieraprēķinu veikšanai.<br>
#
# Aprēķinu sāksim, ielādējot datus izmēģinājuma režīmam ar kompresijas pakāpi 14.
# Dati ir Matlab formātā, un tos jāpārveido Python piemērotā formātā.
# Ar katru gaisa/degvielas attiecību veikti trīs izmēģinājumi. Izmēģinājumi atšķiras ar aizdedzes apsteidzes leņķi:
# - 20 grādi;
# - 25 grādi;
# - 30 grādi; <br>
# pirms augstākā maiņas punkta.
# Katrā izmēģinājumā reģistrēti 150 motora darba cikli.<br>
# No šiem datiem aprēķināta cilindra spiediena vidēja vērtība, katram datu punktam pie noteikta kloķvārpstas pagrieziena leņķa (CAD).
#
# Lai aprēķinu veiktu ar datiem, kas iegūti ar atšķirīgu gaisa/degvielas attiecību $\lambda$, kodā jāizmaina Lambda vērtība un jāpalaiž aprēķins no jauna, (>>Cell >> Run All)

# %% [markdown]
# <center> <h1> Aprēķinu koda izveide

# %% [markdown]
# <center> <h2> Datu ielāde un sagatavošana

# %%
import numpy as np
import scipy.io as spio # to import matlab
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter, AutoMinorLocator)


# Initial parameters
#Choose air/fuel ratio Lambda according to data: 0.9, 1 or 1.1

Lambda = 0.9

Speed=1500 # rpm

if Lambda==0.9:
    Data = spio.loadmat('Data_L09.mat')
elif Lambda==1:
    Data = spio.loadmat('Data_L1.mat')
elif Lambda==1.1:
    Data = spio.loadmat('Data_L11.mat')
    
# Cylinder Pressure Data
P_Test1 = Data ['P_Mot'] # import variable from mat file
P_Test2 = Data ['P_SA20']
P_Test3 = Data ['P_SA25']
P_Test4 = Data ['P_SA30']

# Engine Torque Data
T_Test1 = Data ['T_Mot'] # import variable from mat file
T_Test2 = Data ['T_SA20']
T_Test3 = Data ['T_SA25']
T_Test4 = Data ['T_SA30']

P_Test1=np.squeeze(P_Test1) #removes axes with length 1
P_Test2=np.squeeze(P_Test2)
P_Test3=np.squeeze(P_Test3)
P_Test4=np.squeeze(P_Test4)

T_Test1=np.squeeze(T_Test1) #removes axes with length 1
T_Test2=np.squeeze(T_Test2)
T_Test3=np.squeeze(T_Test3)
T_Test4=np.squeeze(T_Test4)

# %% [markdown]
# Izpildot augšup esošo koda fragmentu, vizuālu pārmaiņu rezultātos nav, bet ir ielādētas bibliotēkas un mērījuma dati.<br>
# Dati satur tikai spiediena mērījumus cilindrā un uz jaudas stenda nomērīto griezes momentu .<br>
# ***
# Nākamajā koda fragmentā:
# - nozīmējam aizdedzes apsteidzes leņķi (SA - Spark Advance) katrā izmēģinājuma režīmā;
# - izveidojam apzīmējumus diagrammām.

# %%
SA_Test1=0 # Spark Advance, CAD BTDC
SA_Test2=20
SA_Test3=25
SA_Test4=30

#labels for plots

label_Test1='Motoring'
label_Test2='SA 20'
label_Test3='SA 25'
label_Test4='SA 30'

#labels for bar plot
labels_line_all = [label_Test1, label_Test2, label_Test3, label_Test4]
labels_line_fired = [label_Test2, label_Test3, label_Test4]
label_L=', $\lambda$ = '+str(Lambda) #converts to string
#First Figure:
Ff=6;

# %% [markdown]
# <center> <h2> Gāzu spiediena un degkameras tilpuma izmaiņu vienkāršota analīze

# %% [markdown]
# <center> <h3> Motora degkameras tilpuma aprēķins

# %% [markdown]
# Gavenie cilindra, virzuļa un kloķa-klaņa mehānisma ģeometriskie parametri parādīti sekojošā attēlā: <br>
# ![Engine_param.JPG](attachment:Engine_param.JPG)
#
# <div align="right">$[J.B. Heywood, 2018]$ <br> <br>
# <center> 5. att. Cilindra, virzuļa un kloķa-klaņa mehānisma ģeometriskie parametri   <br>
#
#
#
# <div align="left"> Vienādojums cilindra darba tilpuma aprēķinam: <br>
#
#  $$V_d=\frac {\pi \cdot B^2 \cdot L}{4}$$
#  kur<br>
# &emsp;&emsp;$V_d$ - cilindra darba tilpums, $ m^{3};$<br>
# &emsp;&emsp;$B$ - cilindra diametrs, $m;$,<br>
# &emsp;&emsp;$L$ - virzuļa gājiens, $m.$<br>
# Vienādojums kompresijas telpas tilpuma aprēķinam: <br>
#
#  $$V_c=\frac {V_d}{CR-1}$$
#  kur<br>
# &emsp;&emsp;$V_c$ - kompresijas telpas tilpums, $ m^{3};$<br>
# &emsp;&emsp;$CR$ - kompresijas pakāpe.$<br>
# Attālums starp kloķvārpstas asi un virzuļa pirksta asi pie jebkura CAD aprēķināms šādi:
#
# $$s=a \cdot \cos\theta + (l^2-a^2 \cdot sin^2\theta)^\frac{1}{2}$$
#  kur<br>
# &emsp;&emsp;$a$ - kloķa garums, $ m;$<br>
# &emsp;&emsp;$l$ - klaņa garums $m;$,<br>
# &emsp;&emsp;$\theta$ - kloķvārpstas pagrieziena leņķis, $grādi.$<br>
#
# Kloķa garums:
#
# $$a=\frac {L}{2} $$ <br>
#
# Motora cilindra pilnais tilpums pie jebkura CAD aprēķināms šādi:
#
# $$V_\theta=V_c + \frac {\pi \cdot B^2 \cdot L}{4} \cdot (l+a+s)$$ <br>
#
# Savukārt motora cilindra pilnā tilpuma diferenciālis pie jebkura CAD analītiski aprēķināms šādi:
#
# $$\frac {dV_\theta}{d \theta}=\frac {\pi \cdot B^2 }{4} \cdot \left(\frac {a \cdot sin\theta + a^2 \cdot sin 2  \theta}{\sqrt{2\cdot(l^2-a^2 \cdot sin^2\theta}}\right) \cdot \frac {\pi}{180} $$ <br>
#
# Var izlīdzēties arī ar vienkāršāku diferencēšanas paņēmienu. Tā ir vienkārša iepriekšējā mērījuma punkta rezultāta atņemšana no nākošā:
#
# $$ \frac {dV_\theta}{d \theta}=\frac {V_{\theta(i+1)} - V_{\theta(i)}} {\theta_{(i+1)} - \theta_{(i)}} $$
#
#  kur<br>
# &emsp;&emsp;$i$ - datu punkts (spiediens un CAD kādā motora darba cikla brīdī).<br>
#
# Nākamajā koda fragmentā izsaucam funkciju, (atsevišku koda fragmentu), kura uzdevums ir aprēķināt nepieciešamos cilidra tilpuma paramaterus:
# - kloķvārpstas pagrieziena lenķi katrā aprēķinu solī (CAD);
# - cilindra darba tilpumu (Vd);
# - kompresijas telpas tilpumu (Vc);
# - cilindra pilno tilpumu pie katra kloķvārpstas pagrieziena grāda (Vth);
# - cilindra tilpuma izmaiņas (diferenciāli), kloķvārpstai pagriežoties par noteiktu leņķi (dVth). <br>
# Šeit kodā ir iekļauts tikai funkcijas faila un funkcijas nosaukums, tās arguments (šajā gadījumā tikai kompresijas pakāpe) un aprēķinu rezultāti.
# Pats funkcijas kods ir atverams un apskatāms šī projekta galvenajā direktorijā, faila nosaukums, ***fc_volume.py*** <br>
#
#
# Tajā ir iekļauti motora sadegšanas kameras izmēri un vienādojumi aprēķinu veikšanai.<br>

# %%
def volume ():


    import numpy as np

    cad = np.linspace(0.1, 720, 7200)



    B=0.081 #Bore ,m
    s=0.077 #Stroke, m
    r=s/2# klokja garums, m
    L=0.13 # klanja garums, m 
    A=np.pi*(B/2)**2 # virsmas laukums, m2
    Vd=A*s # darba tilpums, m3

  
    CR = 9.5

    Vc=Vd/(CR-1)


    scad=L+r-(r*np.cos(np.radians(cad))+(L**2-r**2*np.sin(np.radians(cad))**2)**(1/2))

    Vth=Vc+A*scad

    #Vthm=np.roll(Vth,1) #shift array
    #dVth=Vth - Vthm
    
    dVth =(r*(np.sin(np.radians(cad)))+(r**2*(np.sin(2*np.radians(cad))))/(2*(L**2-r**2*(np.sin(np.radians(cad))**2))**(1/2)))*((np.pi*B**2)/4)*(np.pi/180)*0.1
 
    
    return Vd, Vc, Vth, dVth, cad


#from fc_volume_4F import volume #call function to calculate volume
Vd, Vc, Vth, dVth, cad =volume ()

# %% [markdown]
# Cilindra tilpuma izmaiņas  visā motora darba ciklā varam aplūkot, izveidojot koda fragmentu, kas ģenerē sekojošu diagrammu:

# %%
#Create cylinder volume plot

fig, ax = plt.subplots()
ax.grid()
ax.set_ylabel('Volume, $cm^3$')
F=str(Ff)
ax.set_xlabel('CAD \n \n Fig. '+F+'. Cylinder Volume During Engine Cycle')
Ff=Ff+1

maxval=np.max(Vth*10**6)
ylim=maxval+50
ax.set_xlim(-360, 360)
ax.set_ylim(0, ylim)

ax.xaxis.set_major_locator(MultipleLocator(60)) # distribute major ticks on x axis

line, = ax.plot(cad-360, Vth*10**6, label=('Volume'))

plt.show()

# %% [markdown]
# <center> <h3> Gāzes spiediens cilindrā motora darba ciklā

# %% [markdown]
# Tagad, kad ir kloķvārpstas leņķa vektors $CAD$ (skaitļu rinda 0.1, 0.2 ... 720), kas sagatavota ar funkciju ***volume***, varam izveidot cilindra spiediena izmaiņu diagrammas, sastādot kodu.  <br>
# Kodā lietojam rīkus no papildus bibliotēkas Matplotlib. Šīs bibliotēkas sniegtās iespējas ir plašas un labi dokumentātas. <br>Ieslēdzam tīklu (grid), asīm piešķiram nosaukumus un pieliekam mērvienības.<br>
# Tad izveidojam kodu, kas uzspiež vertikālās (y) ass maksimālo garumu, atkarībā no datu maksimālās vērtības.<br>
# Uzspiežam vērtību sadalījumu uz horizontālās (x) ass.<br>
# Liekam parādīt datu leģendu.<br>
# Visbeidzot liekam parādīt rezultātu.

# %%
# Create cylinder pressure plot
fig, ax = plt.subplots()
ax.grid()
ax.set_ylabel('Pressure, bar')
F=str(Ff)
ax.set_xlabel('CAD \n \n Fig. '+F+'. Pressure changes in cylinder'+label_L)
Ff=Ff+1
maxval=np.max([np.max(P_Test1), np.max(P_Test2), np.max(P_Test3), np.max(P_Test4)])
ylim=maxval+5
ax.set_xlim(-100, 100)
ax.set_ylim(0, ylim)
ax.xaxis.set_major_locator(MultipleLocator(20)) # distribute major ticks on x axis
line, = ax.plot(cad-360, P_Test1, label=label_Test1)
line, = ax.plot(cad-360, P_Test2, label=label_Test2)
line, = ax.plot(cad-360, P_Test3, label=label_Test3)
line, = ax.plot(cad-360, P_Test4, label=label_Test4)
ax.legend()
plt.show()

# %% [markdown]
# Redzams, ka brīvgriešanas režīmā motors ir darbojies kā kompresors, toties režīmos ar degvielas padevi spiediens cilndrā palielinājies, tuvojoties virzuļa augšējam maiņas punktam (0 CAD).<br> Lai gan degvielas daudzums visos režīmos ar vienādu gaisa/degvielas attiecību ir līdzīgs, spiediena pieauguma raksturu nozīmīgi ietekmē aizdedezes apsteidzes lenķis (SA).
# ***
# <br>

# %% [markdown]
# <center> <h3> Spiediena un tilpuma diagramma

# %% [markdown]
# Pielietojot aprēķinātās motora tilpuma izmaiņas, var izveidot spiediena/ tilpuma diagrammu, kurā vizuāli redzama motora darba cikla norise:
# - ieplūde;
# - saspiede;
# - izplete;
# - izplūde. <br>
#
# Tāpat var redzēt gāzu paveiktā darba un sūknēšanas darba lielumu (laukumu ko aptver līknes)

# %%
# Create cylinder pressure/volume plot
fig, ax = plt.subplots()
ax.grid() #create grid
ax.set_ylabel('Pressure, bar')
F=str(Ff)
ax.set_xlabel('Volume, $cm^3$ \n \n Fig. '+F+'. Pressure/ volume diagram'+label_L)
Ff=Ff+1
maxval=np.max([np.max(P_Test1), np.max(P_Test2), np.max(P_Test3), np.max(P_Test4)])
ylim=maxval+5
ax.set_xlim(0, 500) #set axe limits
ax.set_ylim(0, ylim)
line, = ax.plot(Vth*10**6, P_Test1, label=label_Test1) #create multilple line plots
line, = ax.plot(Vth*10**6, P_Test2, label=label_Test2)
line, = ax.plot(Vth*10**6, P_Test3, label=label_Test3)
line, = ax.plot(Vth*10**6, P_Test4, label=label_Test4)
ax.legend()
plt.show()

# %% [markdown]
# <center> <h3> Spiediena un tilpuma digramma logaritmiskā skalā

# %% [markdown]
# Gāzu apmaiņas un sadedzes process labāk redzams, ja p/V diagrammu izveido logaritmiskā skalā. Saspiedes procesa beigās un izplete procesa sākumā, posmā, kurā diagrammas līnija ir izliekta, notiek sadedzes process.

# %%
# Create cylinder pressure/volume log plot
fig, ax = plt.subplots()
ax.grid() #create grid
ax.set_ylabel('log Pressure, bar')
F=str(Ff)
ax.set_xlabel('Volume, $cm^3$ \n \n Fig. '+F+'. Pressure/ volume diagram in log scale'+label_L)
Ff=Ff+1
maxval=np.log(np.max([np.max(P_Test1), np.max(P_Test2), np.max(P_Test3), np.max(P_Test4)]))
ylim=maxval+5
#ax.set_xlim(0, 750) #set axe limits
#ax.set_ylim(0, ylim)
ax.set_xscale('log')
ax.set_yscale('log')
ax.xaxis.set_major_locator(MultipleLocator(30)) # distribute major ticks on x axis
ax.yaxis.set_major_locator(MultipleLocator(10)) # distribute major ticks on y axis
line, = ax.plot((Vth*10**6), (P_Test1), label=label_Test1) #create multilple line plots
line, = ax.plot(Vth*10**6, P_Test2, label=label_Test2)
line, = ax.plot(Vth*10**6, P_Test3, label=label_Test3)
line, = ax.plot(Vth*10**6, P_Test4, label=label_Test4)
ax.legend()
plt.show()

# %% [markdown]
# <center> <h3> Spiediena izmaiņu motora cilindrā raksturojums

# %% [markdown]
# ***
# $5.$ $attēlā$ parādīto cilnidra spiediena diagrammu var analizēt, lai noteiktu maksimālo spiedienu katrā izmēģinājuma režīmā, kā arī maksimālā spiediena brīdi motora darba ciklā, jeb maksimālā spiediena lenķi. <br>
# To var paveikt, uzrakstot kodu. Šim uzdevumam sarakstīts kods un izveidota atsevišķa funkcija, kurai var nosūtīt cilnidra spiediena datus un saņemt divus rezultātus:
# - maksimālo spiedienu;
# - maksimālā spiediena leņķi. <br>
# Funkcijas kods ir atverams un apskatāms šī projekta galvenajā direktorijā, faila nosaukums, fc_maxp.py <br>
# Importējam funkciju un izsaucam to 4 reizes:

# %%
def maxp (cyl_p, cad): #deifine function
    
    import numpy as np
    index_MaxP=np.argmax(cyl_p) #find index of Maxximal pressure 
    PMax=cyl_p[index_MaxP]  # Find maximal pressure value
    PMax_cad=cad[index_MaxP]-360  # find maximal pressure angle
    
    return (PMax, PMax_cad) #returns results


PMax_Test1, PMax_cad_Test1 =maxp (P_Test1, cad)
PMax_Test2, PMax_cad_Test2 =maxp (P_Test2, cad)
PMax_Test3, PMax_cad_Test3 =maxp (P_Test3, cad)
PMax_Test4, PMax_cad_Test4 =maxp (P_Test4, cad)

# %% [markdown]
# <center> <h3> Maksimālais spiediens cilindrā motora darba ciklā

# %% [markdown]
# Maksimālo spiedienu visos izmēģinājumu režīmos varam attēlot grafiski, sastādot kodu:

# %%
# Create bar plot for Pmax
Pmax = [PMax_Test1, PMax_Test2 ,PMax_Test3,PMax_Test4]

x = np.arange(np.size(Pmax)) # creates array for bar order
fig, ax = plt.subplots()
plt.bar(x, Pmax,width=0.3, color=['C0','C1', 'C2', 'C3'])

for index, value in enumerate(x):
    plt.text(value, (Pmax[index]+2), str(np.round(Pmax[index],1)),horizontalalignment='center')
    
ax.set_ylabel('Pressure, bar')
F=str(Ff)
ax.set_xlabel('Test Mode \n \n Fig. '+F+'. Maximal Pressure'+label_L)
Ff=Ff+1

ylim=np.round((np.max(Pmax)+10),2)
ax.set_ylim(0, ylim)
plt.xticks(x, labels_line_all)
plt.show()

# %% [markdown]
# <center> <h3> Maksimālā spiediena leņķis

# %% [markdown]
# Savukārt maksimālā spiediena leņķis visos izmēģinājumu režīmos redzams, sastādot līdzīgu kodu:

# %%
# Create bar plot for Pmax cad
Pmax_cad = [PMax_cad_Test2,PMax_cad_Test3,PMax_cad_Test4]

x = np.arange(np.size(Pmax_cad)) # creates array for bar order
fig, ax = plt.subplots()
plt.bar(x, Pmax_cad,width=0.3, color=['C1', 'C2', 'C3'])

for index, value in enumerate(x):
    plt.text(value, (Pmax_cad[index]+0.5), str(np.round(Pmax_cad[index],1)),horizontalalignment='center')
    
ax.set_ylabel('CAD, ATDC')
F=str(Ff)
ax.set_xlabel('Test Mode  \n \n Fig. '+F+'. Maximal Pressure Angle'+label_L)
Ff=Ff+1
ylim=np.round((np.max(Pmax_cad)+2),2)
ax.set_ylim(0, ylim)
plt.xticks(x, labels_line_fired)
plt.show()

# %% [markdown]
# Citu pētnieku veikti eksperimenti parāda, ka ielāko griezes momentu motors attīsta, ja maksimālā spiediena leņķis ir aptuveni 14...16 CAD pēc augstākā maiņas punkta (AMP). <br>
# Noskaidrosim, vai šī tendence ir raksturīga arī Toyota 4AFE motoram, kā arī to, vai un kā gaisa/degvielas attiecība ietekemē maksimālā spiediena leņķi.

# %% [markdown]
# <center> <h3> Griezes moments

# %% [markdown]
# EfektIvā (Brake) griezes momenta mērījums ir veikts ar jaudas stenda bremzi un elektronisku (tenzorezistīvu) spēka devēju.
# Mērījums veikts tāpat kā cilindra spiediena gadījumā - sinhronizēti ar kloķvārpstas griešanos.
#
# Ciindra spiediena un griezes momenta sadalījums motora darba ciklā parādīts 12. attēlā. <br>
# ![torque.JPG](attachment:torque.JPG)
#
# <div align="right">$[J.B. Heywood, 2018]$ <br> <br>
#
# <center> 12. att. Gāzu spiediens motora cilindrā un griezes moments uz kloķvārpstas   <br>
#     <div align="left">
# <br>Redzams, ka pozitīvs griezes rodas tikai vienreiz, īslaicīgi, divu kloķvārpstas apgriezienu laikā. Vairāku cilindru motora gadījumā divu kloķvārpstas apgriezienu laikā būs cilindru skaitam atbilstošs griezes momenta pieaugums.
# Varam apskatīties, kā griezes momenta sadalījums izskatās mūsu pētījumā.<br> Jāuzraksta tikai īss kods, kas nolasa griezes momenta un kloķvārpstas pagrieziena datus un parāda tos diagrammas veidā.

# %%
Ff=Ff+1
#Create brake torque plot

fig, ax = plt.subplots()
ax.grid()
ax.set_ylabel('Torque, $Nm$')
F=str(Ff)
ax.set_xlabel('CAD \n \n Fig. '+F+'. Brake Torque During Engine Cycle, SA20'+label_L)
Ff=Ff+1
maxval=np.max(T_Test2)
minval=np.min(T_Test2)
ylim=maxval+2
ylim_min=minval-2
ax.set_xlim(-360, 360)
ax.set_ylim(ylim_min, ylim)

ax.xaxis.set_major_locator(MultipleLocator(60)) # distribute major ticks on x axis

line, = ax.plot(cad-360, T_Test2)

plt.show()

# %% [markdown]
# Tiešas sinhronizācijas ar cilindra spiediena datiem šajā gadījumā nav, to paši varat apskatīties, modificējot diagrammas kodu, lai redzētu arī cilindra spiediena līkni. Griezes momenta mērījums nedaudz "nokavē", jo no virzuļa līdz jaudas stenda spēka sensoram ir garš, mehānisks, ceļš ar kardānu un dempferiem.

# %%
#Create brake torque plot

fig, ax = plt.subplots()
ax.grid()
ax.set_ylabel('Torque, $Nm$')
F=str(Ff)
ax.set_xlabel('CAD \n \n Fig. '+F+'. Pressure and Brake Torque During Engine Cycle, SA20'+label_L)
Ff=Ff+1

maxval=np.max(T_Test2)
minval=np.min(T_Test2)
ylim=maxval+2
ylim_min=minval-2
ax.set_xlim(-360, 360)
ax.set_ylim(ylim_min, ylim)

ax.xaxis.set_major_locator(MultipleLocator(60)) # distribute major ticks on x axis

ax2 = ax.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Pressure, bar')  

ax2.yaxis.set_major_locator(MultipleLocator(2)) # distribute major ticks on y axis
fig.tight_layout()  # otherwise the right y-label is slightly clipped

line, = ax.plot(cad-360, T_Test2)
line, = ax2.plot(cad-360, P_Test2, color = 'C1')

plt.show()

# %% [markdown]
# Ja būtu vajadzība noskaidrot motora griezes momenta vērtību, tad no šiem, nomērītajiem griezes momenta datiem būtu jārēķina vidējā vērtība ciklā.

# %% [markdown]
# <center> <h3> Vidējais efektīvais spiediens (BMEP)

# %% [markdown]
# Patērētāji griezes momenta nosaukumu atpazīst un labprāt lieto, lai raksturotu motoru darbību. Inženieru vidū plašāk lieto parametru, kas ir proporcionāls griezes momentam, bet nav atkarīgs no motora tilpuma. Ar šo parametru jau esam pazīstami - tas ir vidējais efektīvais spiediens (Brake Mean Effective Pressure, BMEP). <br>
# BMEP būtībā ir motora vienā ciklā paveiktā darba attiecība pret darba tilpumu. Tas raksturo motora darba tilpuma izmantošanu - jo augstāka BMEP vērtība, jo augstāka slodze vai vairāk forsēts motors. <br>
# Šajā uzdevumā BMEP vajag aprēķināt vienam cilindram. To var veikt sekojoši: <br>
# $$ BMEP=\frac {T_b \cdot 2\pi \cdot n\cdot 10^{-5}}{V_d} $$
#
#  kur<br>
# &emsp;&emsp;$BMEP$ - vidējais efektīvais spiediens, bar;<br>
# &emsp;&emsp;$T_b$ - vidējais griezes moments ciklā, vienam cilindram, Nm;<br>
# &emsp;&emsp;$n$ - kloķvāprstas apgriezieni ciklā (4 taktu motoram n=2)<br>
# &emsp;&emsp;$V_d$ - cilindra darba tilpums, $m^3$.
# <br>
# Griezes moments ir mērīts visam motoram, tā vidējā vērtība ciklā jādala ar cilnidru skaitu.<br>
#
# <br>
# Pamēģiniet paši izveidot kodu, kurā ar atesevišķu funkciju tiek aprēķināts BMEP, un rezultāts parādīts diagrammas veidā.
# Kā analogu lietojiet maksimālā spiediena un tā leņķa aprēķinu.

# %% [markdown]
# <center> <h2> Noslēgums

# %% [markdown]
# Šajā reizē jaunas informācjas pietek. <br> <br>
# Izpildiet šī laboratorijas darba uzdevumus Ortus'ā, kur tie ievietoti testa formātā. <br>
#
# Iegūstiet salīdzināmos datus un parametru vērtības, mainot kodā gaisa/degvielas attiecības \lambda vērtību, un atkārtoti palaižot visu kodu ar >> Cell >> Run All. <br>
#
# <br>Turpinājums sekos.

# %% [markdown]
# <center> <h2> Izmantotā literatūra

# %% [markdown]
# 1. *J. B. Heywood*, ***Internal Combustion Engine Fundamentals***, 2018.
# 2. *R. Stone*, ***Internal Combustion Engines***, 1999.
